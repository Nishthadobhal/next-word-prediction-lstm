# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishthadobhal/next-word-prediction-lstm/blob/main/word_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs="""my name is nishtha
i am a computer science student
i enjoy learning artificial intelligence
i like building machine learning projects
i am interested in deep learning
i practice coding every day
i enjoy solving programming problems
i am learning web development
i know html css and javascript
i am working on mern stack projects
i enjoy creating user friendly websites
i like exploring new technologies
i am learning natural language processing
i want to become an ai engineer
i enjoy participating in hackathons
i like building innovative projects
i believe consistency leads to success
i enjoy learning new concepts daily
i am improving my problem solving skills
i like working on real world applications
i enjoy studying neural networks
i am learning about transformers and llms
i enjoy teamwork and collaboration
i want to build impactful technology
i like experimenting with deep learning models
i enjoy improving my coding skills
i am passionate about technology
i enjoy creating smart applications
i am focused on continuous learning
i want to grow my technical knowledge
i enjoy understanding how ai models work
i am curious about future technologies
i enjoy reading about artificial intelligence
i like learning by building projects
i am developing my communication skills
i enjoy exploring data science concepts
i want to work on advanced ai systems
i believe hard work brings improvement
i enjoy debugging and solving errors
i am interested in software engineering
i enjoy learning about cloud technologies
i want to create intelligent applications
i enjoy studying machine learning algorithms
i am building my technical portfolio
i enjoy learning through practical projects
i am motivated to improve every day
i enjoy challenging myself with new tasks
i want to contribute to innovative solutions
i enjoy combining creativity with technology
i believe learning should never stop"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
#tokenizer give unique id toh each word
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)  #total unq words in dictionary
# Out:
# 129

# %%
input_sequence=[]
for sentence in faqs.split('\n'):
  tokenized_sentence=tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequence.append(tokenized_sentence[:i+1])

# %%
input_sequence
# Out:
# [[6, 43],
#  [6, 43, 44],
#  [6, 43, 44, 45],
#  [1, 3],
#  [1, 3, 46],
#  [1, 3, 46, 47],
#  [1, 3, 46, 47, 25],
#  [1, 3, 46, 47, 25, 48],
#  [1, 2],
#  [1, 2, 4],
#  [1, 2, 4, 26],
#  [1, 2, 4, 26, 27],
#  [1, 7],
#  [1, 7, 11],
#  [1, 7, 11, 28],
#  [1, 7, 11, 28, 4],
#  [1, 7, 11, 28, 4, 9],
#  [1, 3],
#  [1, 3, 29],
#  [1, 3, 29, 14],
#  [1, 3, 29, 14, 30],
#  [1, 3, 29, 14, 30, 4],
#  [1, 49],
#  [1, 49, 31],
#  [1, 49, 31, 32],
#  [1, 49, 31, 32, 33],
#  [1, 2],
#  [1, 2, 15],
#  [1, 2, 15, 50],
#  [1, 2, 15, 50, 51],
#  [1, 3],
#  [1, 3, 4],
#  [1, 3, 4, 52],
#  [1, 3, 4, 52, 53],
#  [1, 54],
#  [1, 54, 55],
#  [1, 54, 55, 56],
#  [1, 54, 55, 56, 12],
#  [1, 54, 55, 56, 12, 57],
#  [1, 3],
#  [1, 3, 34],
#  [1, 3, 34, 13],
#  [1, 3, 34, 13, 58],
#  [1, 3, 34, 13, 58, 59],
#  [1, 3, 34, 13, 58, 59, 9],
#  [1, 2],
#  [1, 2, 35],
#  [1, 2, 35, 60],
#  [1, 2, 35, 60, 61],
#  [1, 2, 35, 60, 61, 62],
#  [1, 7],
#  [1, 7, 36],
#  [1, 7, 36, 16],
#  [1, 7, 36, 16, 17],
#  [1, 3],
# ...

# %%
max_len=max([len(x) for x in input_sequence])
max_len
# Out:
# 8

# %% [markdown]
# all input size are different so that we use pad_seq

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequence, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   6,  43],
#        [  0,   0,   0, ...,   6,  43,  44],
#        [  0,   0,   0, ...,  43,  44,  45],
#        ...,
#        [  0,   0,   0, ...,  19,   4, 127],
#        [  0,   0,   0, ...,   4, 127, 128],
#        [  0,   0,   1, ..., 127, 128, 129]], dtype=int32)

# %%
x=padded_input_sequences[:,:-1] #all rows and col except ast col
y=padded_input_sequences[:,-1]  #last columns of all rows

# %%
x.shape
# Out:
# (250, 7)

# %%
y.shape
# Out:
# (250,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=130)

# %%
y.shape
# Out:
# (250, 130)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense,Dropout

# %%
model = Sequential()

model.add(Embedding(input_dim=130,
                    output_dim=100,
                    input_length=7))

model.add(LSTM(150, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(150))
model.add(Dropout(0.2))

model.add(Dense(130, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ...

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.0520 - loss: 4.8579
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0720 - loss: 4.7340
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0720 - loss: 4.5310
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0680 - loss: 4.4498
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0880 - loss: 4.3647
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0720 - loss: 4.3444
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0760 - loss: 4.2564
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0880 - loss: 4.2121
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1040 - loss: 4.1666
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1160 - loss: 4.0756
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1000 - loss: 3.9990
# Epoch 12/100
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

reverse_word_index = {
    index: word
    for word,index in tokenizer.word_index.items()
}

text = "my name"

for i in range(10):

    token_text = tokenizer.texts_to_sequences([text])[0]

    padded_token_text = pad_sequences(
        [token_text],
        maxlen=7,
        padding='pre'
    )

    pred = model.predict(padded_token_text, verbose=0)

    pos = np.argmax(pred)

    next_word = reverse_word_index.get(pos, "")

    text = text + " " + next_word

    print(text)
# Out:
# my name is
# my name is nishtha
# my name is nishtha my
# my name is nishtha my artificial
# my name is nishtha my artificial tasks
# my name is nishtha my artificial tasks systems
# my name is nishtha my artificial tasks systems systems
# my name is nishtha my artificial tasks systems systems systems
# my name is nishtha my artificial tasks systems systems systems systems
# my name is nishtha my artificial tasks systems systems systems systems systems
